# %% [markdown]
# <a href="https://colab.research.google.com/github/Sk8133/AIML-2024/blob/main/AIML01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

list1 = [1,2,3]

list2= [2,2,3]

array1 =np.array(list1)

array2 = np.array(list2)

print(array1 + array2)

print(array1 * array2)

print(array1 / array2)

print(array1 - array2)
# Out:
# [3 4 6]
# [2 4 9]
# [0.5 1.  1. ]
# [-1  0  0]

# %%
people = ['manjula', 'akshitha',' ashwitha' ,'shylu' , 'Varshitha' ]
ageOfPeople = [20, 19 , 18, 25 ,45 ]
Weight = [10,20,30,40,50]
Height =  [1,2,3,4,5]
import matplotlib.pyplot as plt
plt.scatter(Weight, Height)
plt.title('relationship between weight of height is ')
plt.ylabel('height in meters')
plt.xlabel('height in meters')
plt.show()
plt.hist(Weight, color = 'red' , edgecolor = 'k' , alpha = 0.75 , bins=5)
plt.title('relationship between weight of age of people is ')
plt.ylabel('weight in kg')
plt.xlabel('age  in years')
plt.show()

import numpy as np

plt.figure(figsize=(7,5))

plt.hist(Weight, color = 'red' , edgecolor = 'k' , alpha = 0.75 , bins=5)
plt.title('relationship between weight of age of people is ')
plt.ylabel('weight in kg')
plt.xlabel('age  in years')
plt.show()
